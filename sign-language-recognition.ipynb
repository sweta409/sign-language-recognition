# %%
from skimage import transform
from skimage import data
import matplotlib.pyplot as plt
import os
import numpy as np
from skimage.color import rgb2gray
import random
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000000?line=0'>1</a> from skimage import transform
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000000?line=1'>2</a> from skimage import data
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000000?line=2'>3</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'skimage'

# %%
def load_data(data_directory):
    directories = [d for d in os.listdir(data_directory) 
                   if os.path.isdir(os.path.join(data_directory, d))]
    labels = []
    images = []
    for d in directories:
        label_directory = os.path.join(data_directory, d)
        file_names = [os.path.join(label_directory, f) for f in os.listdir(label_directory)]
        for f in file_names:
            images.append(data.imread(f))
            labels.append(ord(d))
    return images, labels

ROOT_PATH="../input/project"
train_data_directory=os.path.join(ROOT_PATH, "train")

images, labels=load_data(train_data_directory)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 2' in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=13'>14</a> ROOT_PATH="../input/project"
#      <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=14'>15</a> train_data_directory=os.path.join(ROOT_PATH, "train")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=16'>17</a> images, labels=load_data(train_data_directory)
#
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 2' in load_data(data_directory)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=0'>1</a> def load_data(data_directory):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=1'>2</a>     directories = [d for d in os.listdir(data_directory)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=2'>3</a>                    if os.path.isdir(os.path.join(data_directory, d))]
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=3'>4</a>     labels = []
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000001?line=4'>5</a>     images = []
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../input/project\\train'

# %%
images_array = np.array(images)
labels_array = np.array(labels)

# Print the number of `images`'s elements
print("Total number of images:",images_array.size)
# Count the number of labels
print("Total No of classes:",len(set(labels_array)))
print("Label Array: ",[chr(X) for X in set(labels)])

# %%
# Determine the (random) indexes of the images that you want to see 
hand_signs = [12,45,65,35]

# Fill out the subplots with the random images that you defined 
for i in range(len(hand_signs)):
    plt.subplot(1, 4, i+1)
    plt.axis('off')
    plt.imshow(images[hand_signs[i]])
    plt.subplots_adjust(wspace=0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 4' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000003?line=3'>4</a> # Fill out the subplots with the random images that you defined
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000003?line=4'>5</a> for i in range(len(hand_signs)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000003?line=5'>6</a>     plt.subplot(1, 4, i+1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000003?line=6'>7</a>     plt.axis('off')
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000003?line=7'>8</a>     plt.imshow(images[hand_signs[i]])
#
# NameError: name 'plt' is not defined

# %%
# Determine the (random) indexes of the images
hand_signs = [300, 1250, 2650, 3000]

# Fill out the subplots with the random images and add shape, min and max values
for i in range(len(hand_signs)):
    plt.subplot(1, 4, i+1)
    plt.axis('off')
    plt.imshow(images[hand_signs[i]])
    plt.subplots_adjust(wspace=0.5)
    plt.show()
    print("shape: {0}, min: {1}, max: {2}".format(images[hand_signs[i]].shape, 
                                                  images[hand_signs[i]].min(), 
                                                  images[hand_signs[i]].max()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 5' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000004?line=3'>4</a> # Fill out the subplots with the random images and add shape, min and max values
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000004?line=4'>5</a> for i in range(len(hand_signs)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000004?line=5'>6</a>     plt.subplot(1, 4, i+1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000004?line=6'>7</a>     plt.axis('off')
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000004?line=7'>8</a>     plt.imshow(images[hand_signs[i]])
#
# NameError: name 'plt' is not defined

# %%
# Get the unique labels 
unique_labels = set(labels)

# Initialize the figure
plt.figure(figsize=(15, 15))

# Set a counter
i = 1

# For each unique label,
for label in unique_labels:
    # You pick the first image for each label
    image = images[labels.index(label)]
    # Define 64 subplots 
    plt.subplot(8, 8, i)
    # Don't include axes
    plt.axis('off')
    # Add a title to each subplot 
    plt.title("Label {0} ({1})".format(chr(label), labels.count(label)))
    # Add 1 to the counter
    i += 1
    # And you plot this first image 
    plt.imshow(image)
    
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 6' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000005?line=0'>1</a> # Get the unique labels
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000005?line=1'>2</a> unique_labels = set(labels)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000005?line=3'>4</a> # Initialize the figure
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000005?line=4'>5</a> plt.figure(figsize=(15, 15))
#
# NameError: name 'labels' is not defined

# %% [markdown]
# # Feature Extraction

# %%
# Resize images
images32 = [transform.resize(image, (28, 28,3)) for image in images]
images32 = np.array(images32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 8' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000007?line=0'>1</a> # Resize images
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000007?line=1'>2</a> images32 = [transform.resize(image, (28, 28,3)) for image in images]
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000007?line=2'>3</a> images32 = np.array(images32)
#
# NameError: name 'images' is not defined

# %% [markdown]
# # Image Conversion to Grayscale

# %%
images32 = rgb2gray(np.array(images32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000009?line=0'>1</a> images32 = rgb2gray(np.array(images32))
#
# NameError: name 'rgb2gray' is not defined

# %%
for i in range(len(hand_signs)):
    plt.subplot(1, 4, i+1)
    plt.axis('off')
    plt.imshow(images32[hand_signs[i]], cmap="gray")
    plt.subplots_adjust(wspace=0.5)
    
plt.show()

print(images32.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 11' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000010?line=0'>1</a> for i in range(len(hand_signs)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000010?line=1'>2</a>     plt.subplot(1, 4, i+1)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000010?line=2'>3</a>     plt.axis('off')
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000010?line=3'>4</a>     plt.imshow(images32[hand_signs[i]], cmap="gray")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Model

# %%
x = tf.placeholder(dtype = tf.float32, shape = [None, 28, 28])
y = tf.placeholder(dtype = tf.int32, shape = [None])
images_flat = tf.contrib.layers.flatten(x)
logits = tf.contrib.layers.fully_connected(images_flat, 100, tf.nn.relu)
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y, logits = logits))
train_op = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)
correct_pred = tf.argmax(logits, 1)
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

print("images_flat: ", images_flat)
print("logits: ", logits)
print("loss: ", loss)
print("predicted_labels: ", correct_pred)

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())

for i in range(201):
        print('EPOCH', i)
        _, accuracy_val = sess.run([train_op, accuracy], feed_dict={x: images32, y: labels})
        if i % 10 == 0:
            print("Loss: ", loss)
        print('DONE WITH EPOCH')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000013?line=0'>1</a> sess = tf.Session()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000013?line=2'>3</a> sess.run(tf.global_variables_initializer())
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000013?line=4'>5</a> for i in range(201):
#
# NameError: name 'tf' is not defined

# %% [markdown]
# # Evaluation

# %%
# Pick 10 random images
sample_indexes = random.sample(range(len(images32)), 10)
sample_images = [images32[i] for i in sample_indexes]
sample_labels = [labels[i] for i in sample_indexes]

# Run the "predicted_labels" op.
predicted = sess.run([correct_pred], feed_dict={x: sample_images})[0]
                        
# Print the real and predicted labels
print(sample_labels)
print(predicted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 16' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000015?line=0'>1</a> # Pick 10 random images
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000015?line=1'>2</a> sample_indexes = random.sample(range(len(images32)), 10)
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000015?line=2'>3</a> sample_images = [images32[i] for i in sample_indexes]
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000015?line=3'>4</a> sample_labels = [labels[i] for i in sample_indexes]
#
# NameError: name 'random' is not defined

# %%
# Display the predictions and the ground truth visually.
fig = plt.figure(figsize=(10, 10))
for i in range(len(sample_images)):
    truth = sample_labels[i]
    prediction = predicted[i]
    plt.subplot(5, 2,1+i)
    plt.axis('off')
    color='green' if truth == prediction else 'red'
    plt.text(40, 10, "Truth:        {0}\nPrediction: {1}".format(chr(truth), chr(prediction)), 
             fontsize=12, color=color)
    plt.imshow(sample_images[i],cmap='gray')

plt.show()

# %%
sess.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Dell\Desktop\PP_Final\sign-language-recognition.ipynb Cell 20' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/PP_Final/sign-language-recognition.ipynb#ch0000019?line=0'>1</a> sess.close()
#
# NameError: name 'sess' is not defined
